# %% [markdown]
# # Week 10 - Neural Networks

# %% [markdown]
# ## Representing Logic Gates as a Classification Problem
# ---

# %% [markdown]
# Logic gates can be modeled as a classification problem where the input data point is classified into either class '0' representing boolean output 0 or class '1' representing boolean output 1.
#
# ![alt text](https://pythonmachinelearning.pro/wp-content/uploads/2017/09/Logic-Gates.png)
#
# <br> For example, the following figure shows how AND gate can be represented as a classification problem. <br>
#
# ![and-gate-classification](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT6HtfY93_f0PLy-MS5UTogRNmrtptQsU3iHXEbQd4_q79eRfVd)
#
# <br> The figure shows one possible decision boundary that will perform the task.

# %% [markdown]
# ### 1) Using logistic regression implement OR gate such that $\hat{y} = OR(x_1, x_2)$ where $x_1$ and $x_2$ are boolean inputs to the gate and $\hat{y}$ is the boolean output from the gate. Plot the data points and the decision boundary, mention which class each decision region represents.

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return(1/(1+np.exp(-x)))

X = np.array([[0,0], [0,1], [1,0], [1,1]])
y = np.array([0, 1, 1, 1])

w = np.array([1,1])
b = -0.5

prob = sigmoid(w[0]*X[:,0] + w[1]*X[:,1] + b)
y_estd = np.round(prob) 

print("The actual values are: ", y)
print("The predicted values are: ", y_estd)

print("\nThe weights are: ", w)
print("The bias is: ", b)

plt.figure()
plt.scatter(X[:,0][y == 0],X[:,1][y == 0], c = 'r', label = "y = 0")
plt.scatter(X[:,0][y == 1],X[:,1][y == 1], c = 'b',label = "y = 1")
plt.plot([-0.5,1],[1,-0.5])
plt.xlim(-0.5,1.5)
plt.ylim(-0.5,1.5)
plt.legend(loc = 1)
plt.title("OR gate")
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()
# Out:
# The actual values are:  [0 1 1 1]
# The predicted values are:  [0. 1. 1. 1.]
#
# The weights are:  [1 1]
# The bias is:  -0.5

# %% [markdown]
# ## Single-Layer Perceptron
# ---

# %% [markdown]
#  The following image represents the architecture of a single-layer perceptron.
#
# ![single-layer-perceptron](https://www.simplilearn.com/ice9/free_resources_article_thumb/general-diagram-of-perceptron-for-supervised-learning.jpg)

# %% [markdown]
# ### 2) Now implement OR gate using a single-layer perceptron with step-function as activation. Specify one set of weights $w_1, w_2$ and bias $b$ that will perform this task. Plot the data points and the decision boundary, mention which class each decision region represents.<br>Note: You have to define the perceptron yourself, without using `scikit-learn`.

# %%
w = np.array([0.2,0.2])
b = 0.8

# applying step activation function
z = w[0]*X[:,0] + w[1]*X[:,1] + b
y_estd = np.floor(z)


print("The actual values are: ", y)
print("The estimated values are (using step function) :", y_estd)

print("\nweights are :")
print("w1 :",w[0])
print("w2 :",w[1])
print("bias :", b)

plt.figure()
plt.scatter(X[:,0][y == 0],X[:,1][y == 0], c = 'r', label = "y = 0")
plt.scatter(X[:,0][y == 1],X[:,1][y == 1], c = 'b',label = "y = 1")
plt.plot([-0.5,1],[1,-0.5])
plt.xlim(-0.5,1.5)
plt.ylim(-0.5,1.5)
plt.legend(loc = 1)
plt.title("OR gate (Single - Layer Perceptron)")
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()
# Out:
# The actual values are:  [0 1 1 1]
# The estimated values are (using step function) : [0. 1. 1. 1.]
#
# weights are :
# w1 : 0.2
# w2 : 0.2
# bias : 0.8

# %% [markdown]
# ### 3) Do you observe any similarities between logistic regression and single-layer perceptron? What activation function should be used in the perceptron to get the same functionality as logistic regression?

# %% [markdown]
# The sigmoid activation function should be used in single layered perceptron to get same functionality as Logistic Regression. The similarity is both generate linear decision boundaries.

# %% [markdown]
# ### 4) Now implement AND gate using a single-layer perceptron with step-function as activation. Specify one set of weights $w_1, w_2$ and bias $b$ that will perform this task. Plot the data points and the decision boundary, mention which class each decision region represents.<br>Note: You have to define the perceptron yourself, without using `scikit-learn`.

# %%
X = np.array([[0,0], [0,1], [1,0], [1,1]])
y = np.array([0, 0, 0, 1])

w = np.array([0.2,0.2])
b = 0.6

# applying step activation function
z = w[0]*X[:,0] + w[1]*X[:,1] + b
y_estd = np.floor(z)

print("The actual values are: ", y)
print("The predicted values are: ", y_estd)

print("\nThe weights are: ", w)
print("The bias is: ", b)

plt.figure()
plt.scatter(X[:,0][y == 0],X[:,1][y == 0], c = 'r', label = "y = 0")
plt.scatter(X[:,0][y == 1],X[:,1][y == 1], c = 'b',label = "y = 1")
plt.plot([-0.5,2],[2,-0.5])
plt.xlim(-0.5,1.5)
plt.ylim(-0.5,1.5)
plt.legend(loc = 1)
plt.title("AND gate (Single - Layer Perceptron)")
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()
# Out:
# The actual values are:  [0 0 0 1]
# The predicted values are:  [0. 0. 0. 1.]
#
# The weights are:  [0.2 0.2]
# The bias is:  0.6

# %% [markdown]
# ### 5) Can you construct an XOR gate similarly using a single-layer perceptron? Explain your answer.

# %% [markdown]
# No, we cannot achieve complete classification using linear classifier (single layer perceptron) for a XOR gate as there is always a misclassification. A non-linear decision boundary is required.

# %% [markdown]
# ## Multi-Layer Perceptron
#
# ---

# %% [markdown]
# The following image represents the architecture of a multi-layer perceptron with a singe hidden layer.
# ![alt text](https://missinglink.ai/wp-content/uploads/2018/11/multilayer-perceptron.png)
# <br> Similarly we can introduce multiple hidden layers of different sizes to form a neural network.

# %% [markdown]
# ### 6) Now implement XOR gate using a multi-layer perceptron with one hidden layer of two neurons and step function as activation, such that $\hat{y} = XOR(x_1, x_2)$ where $x_1$ and $x_2$ are boolean inputs to the gate and $\hat{y}$ is the boolean output from the gate.<br>Note: You have to define the perceptron yourself, without using `scikit-learn`. <br> <br> Plot and visualize the decision boundary for each neuron in the network (with respect to the inputs $x_1$ and $x_2$, in the same plot) and specify which class each region represents. <br> <br> Hint: Decompose the XOR gate into basic gates of OR, AND and NOT and manually define weights accordingly. (refer to the link provided in the reading material)

# %%
X = np.array([[0,0], [0,1], [1,0], [1,1]])
y = np.array([0, 1, 1, 0])

# input weights
w00 = 0.35
w01 = -0.6
b0 = 0.7
w10 = 0.4
w11 = -0.7
b1 = 1.8
# hidden layer weights and bias
w1 = 0.2
w2 = 0.2
b2 = 0.6

# computing hidden layer
z1 = np.floor(w00*X[:,0] + w10*X[:,1] + b0)
z2 = np.floor(w01*X[:,0] + w11*X[:,1] + b1)

y_estd = np.floor(w1*z1 + w2*z2 + b2)

print("The actual values are: ", y)
print("The predicted values are: ", y_estd)

plt.figure()
plt.scatter(X[:,0][y == 0],X[:,1][y == 0], c = 'r', label = "y = 0")
plt.scatter(X[:,0][y == 1],X[:,1][y == 1], c = 'b',label = "y = 1")
plt.plot([-0.5,2],[2,-0.5], c = 'b')
plt.plot([-0.5,1],[1,-0.5] , c = 'b')
plt.xlim(-0.1,1.5)
plt.ylim(-0.1,1.5)
plt.legend(loc = 1)
plt.title("XOR gate (Multi- Layer Perceptron)")
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()
# Out:
# The actual values are:  [0 1 1 0]
# The predicted values are:  [0. 1. 1. 0.]

# %% [markdown]
# The region between the two lines is for class-1 and outside is for class-2.

# %% [markdown]
# ### 7) From what you observed in the above exercises, explain what drawback of single-layer perceptron can be overcome by multi-layer perceptron using hidden layers.

# %% [markdown]
# The drawback of single layer perceptron is it always requires a linear separable data and in general can't fit a non-linear decision boundary. This can be overcome by multi- layered perceptron and the use of non-linear activation function other than step activation function.

# %% [markdown]
# ## MLP Classification on Synthetic Dataset
# ---

# %% [markdown]
# ### 8) Load the synthetic dataset from '`synth_data_train.npz`' and `'synth_data_test.npz'` containing train and test data. Visualize the data in a 2D plot. <br> Note: `mglearn.discrete_scatter(x1, x2, y)` from `mglearn` library provides good visualization

# %%
import mglearn
train = np.load('synth_data_train.npz')
test = np.load('synth_data_test.npz')
X_train = train['X']
Y_train = train['y']
X_test = test['X']
Y_test = test['y']

data_x = np.vstack((X_train, X_test))
data_y = np.append(Y_train, Y_test)

# visualizing the dataset
mglearn.discrete_scatter(data_x[:,0], data_x[:,1], data_y)
plt.title('Synthetic Data')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()
# Out:
# F:\Anaconda\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# F:\Anaconda\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# ### 9) Using `MLPClassifier` from `scikit-learn` library, fit a binary classifier to the given data. Use `max_iter=1000`, `random_state=0` and the rest as default parameters for the classifier.
#
# ### Visualize the decision boundary of the classifier in a 2D plot along with the train data points used to fit the classifier (in the same plot). <br> Note: `mglearn.plots.plot_2d_separator(classifier, X, fill=True, alpha=.3)` provides good visualization of the decision boundary
#
# ### Report the train and test score of the above classifier on the given train and test data.

# %%
from sklearn.neural_network import MLPClassifier
mlp_clf = MLPClassifier(max_iter = 1000, random_state = 0)
mlp_fit = mlp_clf.fit(X_train, Y_train)

print("The train score is: ", mlp_clf.score(X_train, Y_train))
print("The test score is: ", mlp_clf.score(X_test, Y_test))

plt.figure()
mglearn.discrete_scatter(data_x[:,0], data_x[:,1], data_y)
mglearn.plots.plot_2d_separator(mlp_clf, X_train, fill=True, alpha=.3)
plt.title('Synthetic Data')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()
# Out:
# The train score is:  0.9533333333333334
# The test score is:  0.8

# %% [markdown]
# ### 10) Using `MLPClassifier`from `scikit-learn` library, fit a binary classifier to the given data, using a single hidden layer of size <br>(i) 2 (ii) 3 (iii) 5 (iv) 7 (v) 10 (vi) 15. <br>Use `max_iter=3000`, `random_state=0` and the rest as default parameters for the classifier.
#
# ### For each of the above cases, visualize the decision boundary of the classifier in a 2D plot along with the train data points used to fit the classifier. <br> Note: `mglearn.plots.plot_2d_separator(classifier, X, fill=True, alpha=.3)` provides good visualization of the decision boundary
#
# ### For each of the above cases, report train and test score of the classifier on the given data.

# %%
import warnings
warnings.filterwarnings("ignore")

hid_size = [2,3,5,7,10,15]
for i in hid_size:
    mlp_clf = MLPClassifier(hidden_layer_sizes = i, max_iter = 3000, random_state = 0)
    mlp_fit = mlp_clf.fit(X_train, Y_train)
    
    print("The train score for hidden layer size - {} is: ".format(i), mlp_clf.score(X_train, Y_train))
    print("The test score for hidden layer size - {} is: ".format(i), mlp_clf.score(X_test, Y_test))

    plt.figure()
    mglearn.discrete_scatter(data_x[:,0], data_x[:,1], data_y)
    mglearn.plots.plot_2d_separator(mlp_clf, X_train, fill=True, alpha=.3)
    plt.title('Synthetic Data (Hidden layer Size - {})'.format(i))
    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.show()
# Out:
# The train score for hidden layer size - 2 is:  0.6266666666666667
# The test score for hidden layer size - 2 is:  0.64
# The train score for hidden layer size - 3 is:  0.6933333333333334
# The test score for hidden layer size - 3 is:  0.68
# The train score for hidden layer size - 5 is:  0.72
# The test score for hidden layer size - 5 is:  0.66
# The train score for hidden layer size - 7 is:  0.9266666666666666
# The test score for hidden layer size - 7 is:  0.82
# The train score for hidden layer size - 10 is:  0.94
# The test score for hidden layer size - 10 is:  0.86
# The train score for hidden layer size - 15 is:  0.96
# The test score for hidden layer size - 15 is:  0.82

# %% [markdown]
# ### 11) Using `MLPClassifier`from `scikit-learn` library, fit a binary classifier to the given data, using <br>(a) one hidden layer of size 15 <br>(b) two hidden layers each of size 5 <br>(c) three hidden layers each of size 5. <br>Use `max_iter=2000`, `random_state=0` and the rest as default parameters for the classifier.
#
# ### For each of the above cases, visualize the decision boundary of the classifier in a 2D plot along with the train data points used to fit the classifier. <br> Note: `mglearn.plots.plot_2d_separator(classifier, X, fill=True, alpha=.3)` provides good visualization of the decision boundary
#
# ### For each of the above cases, report train and test score of the classifier on the given data.

# %%
# (a) - one hidden layer of size - 15
mlp_clf = MLPClassifier(hidden_layer_sizes = 15, max_iter = 2000, random_state = 0)
mlp_fit = mlp_clf.fit(X_train, Y_train)

print("The train score for single hidden layer size of 15 is: ", mlp_clf.score(X_train, Y_train))
print("The test score for single hidden layer size of 15 is: ", mlp_clf.score(X_test, Y_test))

plt.figure()
mglearn.discrete_scatter(data_x[:,0], data_x[:,1], data_y)
mglearn.plots.plot_2d_separator(mlp_clf, X_train, fill=True, alpha=.3)
plt.title('Synthetic Data (single hidden layer of size 15)')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()

# (b) - two hidden layer of size - 5 each
mlp_clf_2 = MLPClassifier(hidden_layer_sizes = (5,5), max_iter = 2000, random_state = 0)
mlp_fit_2 = mlp_clf_2.fit(X_train, Y_train)

print("The train score for two hidden layers each of size 5 is: ", mlp_clf_2.score(X_train, Y_train))
print("The test score for two hidden layers each of size 5 is: ", mlp_clf_2.score(X_test, Y_test))

plt.figure()
mglearn.discrete_scatter(data_x[:,0], data_x[:,1], data_y)
mglearn.plots.plot_2d_separator(mlp_clf_2, X_train, fill=True, alpha=.3)
plt.title('Synthetic Data (two hidden layers of size 5 each)')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()
          
# (c) - three hidden layer of size - 5 each
mlp_clf_3 = MLPClassifier(hidden_layer_sizes = (5,5,5), max_iter = 2000, random_state = 0)
mlp_fit_3 = mlp_clf_3.fit(X_train, Y_train)

print("The train score for three hidden layers each of size 5 is: ", mlp_clf_3.score(X_train, Y_train))
print("The test score for three hidden layers each of size 5 is: ", mlp_clf_3.score(X_test, Y_test))

plt.figure()
mglearn.discrete_scatter(data_x[:,0], data_x[:,1], data_y)
mglearn.plots.plot_2d_separator(mlp_clf_3, X_train, fill=True, alpha=.3)
plt.title('Synthetic Data (three hidden layers of size 5 each)')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()
# Out:
# The train score for single hidden layer size of 15 is:  0.96
# The test score for single hidden layer size of 15 is:  0.82
# The train score for two hidden layers each of size 5 is:  0.9533333333333334
# The test score for two hidden layers each of size 5 is:  0.84
# The train score for three hidden layers each of size 5 is:  0.9733333333333334
# The test score for three hidden layers each of size 5 is:  0.78

# %% [markdown]
# ### 12) From your observations in the above exercises, what is the effect of adding more hidden layers and how is it different from adding more neurons to the same hidden layer?

# %% [markdown]
# ### Activation Functions<br>
# The following image shows some basic and commonly used activation functions.
# ![alt text](https://www.kdnuggets.com/wp-content/uploads/activation.png)

# %% [markdown]
# ### 13) Using `MLPClassifier`from `scikit-learn` library, fit a binary classifier to the given data, using one hidden layer of size 10 and activation function as <br>(a) identity <br>(b) sigmoid <br>(c) tanh <br>(d) relu. <br>Use `max_iter=2000`, `random_state=0` and the rest as default parameters for the classifier.
#
# ### For each of the above cases, visualize the decision boundary of the classifier in a 2D plot along with the train data points used to fit the classifier. <br> Note: `mglearn.plots.plot_2d_separator(classifier, X, fill=True, alpha=.3)` provides good visualization of the decision boundary
#
# ### For each of the above cases, report train and test score of the classifier on the given data.

# %%
activ_func = ['identity', 'logistic', 'tanh', 'relu']
for i in activ_func:
    mlp_clf = MLPClassifier(hidden_layer_sizes = 10, activation = i ,max_iter = 2000, random_state = 0)
    mlp_fit = mlp_clf.fit(X_train, Y_train)
    
    print("The train score for {} activation function is: ".format(i), mlp_clf.score(X_train, Y_train))
    print("The test score for {} activation function is: ".format(i), mlp_clf.score(X_test, Y_test))

    plt.figure()
    mglearn.discrete_scatter(data_x[:,0], data_x[:,1], data_y)
    mglearn.plots.plot_2d_separator(mlp_clf, X_train, fill=True, alpha=.3)
    plt.title('Synthetic Data (Activation function - {})'.format(i))
    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.show()
# Out:
# The train score for identity activation function is:  0.52
# The test score for identity activation function is:  0.5
# The train score for logistic activation function is:  0.5466666666666666
# The test score for logistic activation function is:  0.48
# The train score for tanh activation function is:  0.94
# The test score for tanh activation function is:  0.82
# The train score for relu activation function is:  0.94
# The test score for relu activation function is:  0.86

# %% [markdown]
# ### 14) Which activation function gives the best classifier for the given dataset and why? Are there any drawbacks in using the other activation functions?

# %% [markdown]
# ## MLP Classification on MNIST Dataset
# ---

# %% [markdown]
# ### 15) Load the MNIST dataset from `sklearn.datasets.fetch_openml`. Visualize the data.

# %%
from sklearn.datasets import fetch_openml
X, y = fetch_openml('mnist_784', version=1, return_X_y=True)

# %%
print(X.shape)
# Out:
# (70000, 784)

# %%
# visualizing the handwritten digits in the dataset 
images = np.reshape(X, (70000,28,28))
print(" The images in the given dataset are as follows:")
plt.figure(figsize = (30,15))
images_and_labels = list(zip(images, y))
for index, (image, label) in enumerate(images_and_labels[:10]):
    plt.subplot(1, 10, index + 1)
    plt.axis('off')
    plt.imshow(image)
    plt.title('{}'.format(label))
# Out:
#  The images in the given dataset are as follows:

# %%
from sklearn.model_selection import train_test_split

# train test split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0) 
# X_train, X_test = X[:60000], X[60000:]
# y_train, y_test = y[:60000], y[60000:]

# %% [markdown]
# ### 16) Fit an `MLPClassifier` with one hidden layer of 50 neurons (use `max_iter=20`, `alpha=1e-4`, `solver='sgd'`, `tol=1e-4`, `random_state=1`) <br> Visualize the weights of the hidden layer. <br>Hint: For each neuron in the hidden layer, reshape the weights to form a 28x28 grid and visualize them.

# %%
mlp_clf_mnist = MLPClassifier(hidden_layer_sizes = 50, max_iter = 20, alpha = 1e-4, solver = 'sgd', tol = 1e-4, random_state = 1)
mlp_clf_mnist.fit(X_train,y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=50, learning_rate='constant',
#               learning_rate_init=0.001, max_iter=20, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='sgd', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
# visualizing the weights of hidden layer
fig, axes = plt.subplots(4, 4, figsize=(8,8))
vmin, vmax = mlp_clf_mnist.coefs_[0].min(), mlp_clf_mnist.coefs_[0].max()
for coef, ax in zip(mlp_clf_mnist.coefs_[0].T, axes.ravel()):
    ax.matshow(coef.reshape(28, 28), vmin= 0.3* vmin,
               vmax= 0.3* vmax)
    ax.set_xticks(())
    ax.set_yticks(())

plt.show()

# %%
print("Training set score: %f" % mlp_clf_mnist.score(X_train, y_train))
print("Test set score: %f" % mlp_clf_mnist.score(X_test, y_test))
# Out:
# Training set score: 0.903982
# Test set score: 0.891000

# %% [markdown]
# ### 17) What patterns do you observe in the weights that you visualized? Explain why you think these patterns are formed?

# %% [markdown]
# ### 18) Experiment with different parameters of the `MLPClassifier`. You can vary the number of hidden layers, number of neurons in each hidden layer and activation function used for the hidden layers. <br> Report the train and test scores and confusion matrix for each of the cases.

# %% [markdown]
# ### 19) Which one of the above do you think is the optimal model? Give reasons. Report the train-test scores and confusion matrix.

# %% [markdown]
# Answer here.

# %%
# Code here. Use additional text cells if required.
